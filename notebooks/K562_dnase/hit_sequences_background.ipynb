# %%
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.font_manager as fm
import seaborn as sns
import pyfaidx

# %%
font_path = "/users/atwang/fonts/Inter/Inter Variable/Inter.ttf"
prop = fm.FontProperties(fname=font_path)
fm.fontManager.addfont(font_path)

sns.set(style="white", font=prop.get_name())

# %%
fa_path = "/mnt/lab_data2/anusri/chrombpnet/reference/hg38.genome.fa"

hits_path = "/oak/stanford/groups/akundaje/atwang/finemo_gpu_test/K562/background/v10_proj_a_0.6_c_0.0005/hits_unique.tsv"
hits_all = (
    pl.scan_csv(hits_path, separator='\t', quote_char=None)
    .select(["chr", "start_untrimmed", "end_untrimmed", "strand", "motif_name", "hit_coefficient"])
)

# %%
SEQ_ALPHABET = np.array(["A","C","G","T"], dtype="S1")

def one_hot_encode(sequence, dtype=np.int8):
    sequence = sequence.upper()

    seq_chararray = np.frombuffer(sequence.encode('UTF-8'), dtype='S1')
    one_hot = (seq_chararray[None,:] == SEQ_ALPHABET[:,None]).astype(dtype)

    return one_hot


def load_regions_seq(hits, fa_path, motif_width):
    num_hits = hits.height

    sequences = np.zeros((num_hits, 4, motif_width), dtype=np.int8)

    genome = pyfaidx.Fasta(fa_path, one_based_attributes=False)
    
    for ind, row in enumerate(hits.iter_rows(named=True)):
        chrom = row["chr"]
        start = row["start_untrimmed"]
        end = row["end_untrimmed"]
        strand = row["strand"]
        
        seq = one_hot_encode(genome[chrom][start:end].seq)
        if strand == "-":
            seq = seq[::-1,::-1]

        sequences[ind,:,:] = seq

    return sequences

# %%
def filter_hits(hits_all, motif_name):
    hits = (
        hits_all
        .filter(pl.col("motif_name") == motif_name)
        .sort("hit_coefficient", descending=True)
        .collect()
    )
    return hits

# %%
def plot_sequences(sequences):
    data = (sequences * np.array([0, 1, 2, 3])[None,:,None]).sum(axis=1)

    # color_inds = [2, 0, 8, 3]
    # p = sns.color_palette("bright")
    # cmap = ListedColormap([p[i] for i in color_inds])

    colors = {
        'G': [1, .65, 0],
        'T': [1, 0, 0],
        'C': [0, 0, 1],
        'A': [0, .5, 0]
    }
    cmap = ListedColormap([colors[i] for i in ["A","C","G","T"]])

    plt.figure(figsize=(4, 8), dpi=150)
    plt.imshow(data, cmap=cmap, aspect='auto', interpolation='none')
    plt.show()
    plt.close()

# %%
# GATA
hits = filter_hits(hits_all, "pos_patterns.pattern_0")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/finemo_gpu_notebooks/lib/python3.10/site-packages/pyfaidx/__init__.py:1128, in Fasta.__getitem__(self, rname)
#    1127 try:
# -> 1128     return self.records[rname]
#    1129 except KeyError:
#
# KeyError: 'NA'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # GATA
#       <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> hits = filter_hits(hits_all, "pos_patterns.pattern_0")
# ----> <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> sequences = load_regions_seq(hits, fa_path, 30)
#       <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plot_sequences(sequences)
#
# /oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> end = row["end_untrimmed"]
#      <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> strand = row["strand"]
# ---> <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> seq = one_hot_encode(genome[chrom][start:end].seq)
#      <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> if strand == "-":
#      <a href='vscode-notebook-cell://tunnel%2Bnandi/oak/stanford/groups/akundaje/atwang/finemo_gpu/notebooks/hit_sequences_background.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     seq = seq[::-1,::-1]
#
# File ~/miniconda3/envs/finemo_gpu_notebooks/lib/python3.10/site-packages/pyfaidx/__init__.py:1130, in Fasta.__getitem__(self, rname)
#    1128     return self.records[rname]
#    1129 except KeyError:
# -> 1130     raise KeyError("{0} not in {1}.".format(rname, self.filename))
#
# KeyError: 'NA not in /mnt/lab_data2/anusri/chrombpnet/reference/hg38.genome.fa.'

# %%
# CTCF
hits = filter_hits(hits_all, "pos_patterns.pattern_1")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# SP1
hits = filter_hits(hits_all, "pos_patterns.pattern_2")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# BACH
hits = filter_hits(hits_all, "pos_patterns.pattern_3")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# NFIA
hits = filter_hits(hits_all, "pos_patterns.pattern_4")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# GABPA
hits = filter_hits(hits_all, "pos_patterns.pattern_5")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# NFYB
hits = filter_hits(hits_all, "pos_patterns.pattern_6")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# NRF1
hits = filter_hits(hits_all, "pos_patterns.pattern_7")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# CREB1
hits = filter_hits(hits_all, "pos_patterns.pattern_8")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# ZN143
hits = filter_hits(hits_all, "pos_patterns.pattern_9")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# BCL6
hits = filter_hits(hits_all, "pos_patterns.pattern_10")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# ETV4/ELF5/EHF
hits = filter_hits(hits_all, "pos_patterns.pattern_11")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# TFE3
hits = filter_hits(hits_all, "pos_patterns.pattern_12")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# YY1
hits = filter_hits(hits_all, "pos_patterns.pattern_13")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# REST
hits = filter_hits(hits_all, "pos_patterns.pattern_15")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# ZBTB33
hits = filter_hits(hits_all, "pos_patterns.pattern_16")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# ZNF76/143
hits = filter_hits(hits_all, "pos_patterns.pattern_17")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# ZEB/SNA negative
hits = filter_hits(hits_all, "neg_patterns.pattern_1")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# C2H2 negative
hits = filter_hits(hits_all, "neg_patterns.pattern_0")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# SP1 alt
hits = filter_hits(hits_all, "pos_patterns.pattern_21")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# SP1 alt
hits = filter_hits(hits_all, "pos_patterns.pattern_22")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# SP1 alt
hits = filter_hits(hits_all, "pos_patterns.pattern_27")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# SP1 alt
hits = filter_hits(hits_all, "pos_patterns.pattern_30")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# SP1 alt
hits = filter_hits(hits_all, "pos_patterns.pattern_32")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# NFI alt
hits = filter_hits(hits_all, "pos_patterns.pattern_35")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)

# %%
# GC bias
hits = filter_hits(hits_all, "pos_patterns.pattern_14")

sequences = load_regions_seq(hits, fa_path, 30)
plot_sequences(sequences)
